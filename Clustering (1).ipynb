# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
df = pd.read_excel("https://raw.githubusercontent.com/ygtech27/Datasets/refs/heads/main/EastWestAirlines.xlsx",sheet_name= 'data')
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?
# 0          0
# 1          0
# 2          0
# 3          0
# 4          1
# ...      ...
# 3994       1
# 3995       1
# 3996       1
# 3997       0
# 3998       0
#
# [3999 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
df.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# min       1.000000       0.000000      0.00000           0.000000
# 25%       1.000000    1250.000000      3.00000           0.000000
# 50%       1.000000    7171.000000     12.00000           0.000000
# 75%       1.000000   23800.500000     17.00000         311.000000
# max       5.000000  263685.000000     86.00000       30817.000000
#
#        Flight_trans_12  Days_since_enroll       Award?
# count      3999.000000         3999.00000  3999.000000
# mean          1.373593         4118.55939     0.370343
# std           3.793172         2065.13454     0.482957
# min           0.000000            2.00000     0.000000
# 25%           0.000000         2330.00000     0.000000
# 50%           0.000000         4096.00000     0.000000
# 75%           1.000000         5790.50000     1.000000
# max          53.000000         8296.00000     1.000000

# %%
df.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
for i in df.columns:
    data =df.copy()
    data[i].hist(bins=10)
    plt.ylabel("Count")
    plt.title(i)
    plt.show()

# %%
##Boxplot
ot=df.copy()
fig, axes=plt.subplots(12,1,figsize=(20,18),sharex=False,sharey=False)
sns.boxplot(x='ID#',data=ot,palette='crest',ax=axes[0])
sns.boxplot(x='Balance',data=ot,palette='crest',ax=axes[1])
sns.boxplot(x='Qual_miles',data=ot,palette='crest',ax=axes[2])
sns.boxplot(x='cc1_miles',data=ot,palette='crest',ax=axes[3])
sns.boxplot(x='cc2_miles',data=ot,palette='crest',ax=axes[4])
sns.boxplot(x='cc3_miles',data=ot,palette='crest',ax=axes[5])
sns.boxplot(x='Bonus_miles',data=ot,palette='crest',ax=axes[6])
sns.boxplot(x='Bonus_trans',data=ot,palette='crest',ax=axes[7])
sns.boxplot(x='Flight_miles_12mo',data=ot,palette='crest',ax=axes[8])
sns.boxplot(x='Flight_trans_12',data=ot,palette='crest',ax=axes[9])
sns.boxplot(x='Days_since_enroll',data=ot,palette='crest',ax=axes[10])
sns.boxplot(x='Award?',data=ot,palette='crest',ax=axes[11])
plt.tight_layout(pad=2.0)
# Out:
# /tmp/ipython-input-33-4216787434.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='ID#',data=ot,palette='crest',ax=axes[0])
# /tmp/ipython-input-33-4216787434.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Balance',data=ot,palette='crest',ax=axes[1])
# /tmp/ipython-input-33-4216787434.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Qual_miles',data=ot,palette='crest',ax=axes[2])
# /tmp/ipython-input-33-4216787434.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='cc1_miles',data=ot,palette='crest',ax=axes[3])
# /tmp/ipython-input-33-4216787434.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='cc2_miles',data=ot,palette='crest',ax=axes[4])
# /tmp/ipython-input-33-4216787434.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='cc3_miles',data=ot,palette='crest',ax=axes[5])
# /tmp/ipython-input-33-4216787434.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Bonus_miles',data=ot,palette='crest',ax=axes[6])
# /tmp/ipython-input-33-4216787434.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Bonus_trans',data=ot,palette='crest',ax=axes[7])
# /tmp/ipython-input-33-4216787434.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Flight_miles_12mo',data=ot,palette='crest',ax=axes[8])
# /tmp/ipython-input-33-4216787434.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Flight_trans_12',data=ot,palette='crest',ax=axes[9])
# /tmp/ipython-input-33-4216787434.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Days_since_enroll',data=ot,palette='crest',ax=axes[10])
# /tmp/ipython-input-33-4216787434.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Award?',data=ot,palette='crest',ax=axes[11])

# %%
## finding outliers
def outlier_function(df,col):
    q1=df[col].quantile(0.25)
    q3=df[col].quantile(0.75)
    iqr=q3-q1
    upper=q3+(1.5*iqr)
    lower=q1-(1.5*iqr)
    return lower,upper

# %%
outlier_function(df,'ID#')
outlier_function(df,'Balance')
outlier_function(df,'Qual_miles')
outlier_function(df,'cc1_miles')
outlier_function(df,'cc2_miles')
outlier_function(df,'cc3_miles')
outlier_function(df,'Bonus_miles')
outlier_function(df,'Bonus_trans')
outlier_function(df,'Flight_miles_12mo')
outlier_function(df,'Flight_trans_12')
outlier_function(df,'Days_since_enroll')
outlier_function(df,'Award?')
# Out:
# (np.float64(-1.5), np.float64(2.5))

# %%
sns.set_style(style='darkgrid')
sns.pairplot(df)

# %%
##### Data Transformations
### Standardscalar on continious data
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
for column in df.columns:
    if df[column].dtype=='object':
        continue
    df[column]=ss.fit_transform(df[[column]])

df
#creating X variables
X=df.iloc[:,1:]
X
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0       -1.104065          -0.328603        -0.362168           1.395454
# 1       -0.999926          -0.328603        -0.362168           1.379957
# 2       -0.791649          -0.328603        -0.362168           1.411920
# 3       -1.104065          -0.328603        -0.362168           1.372208
# 4        1.499394           1.154932         0.692490           1.363975
# ...           ...                ...              ...                ...
# 3994    -0.791649          -0.185750        -0.098503          -1.315120
# 3995    -0.687511          -0.328603        -0.362168          -1.318994
# 3996    -0.375096          -0.328603        -0.362168          -1.315604
# 3997    -1.104065           0.028531        -0.098503          -1.316088
# 3998    -1.208203          -0.328603        -0.362168          -1.317541
#
#         Award?
# 0    -0.766919
# 1    -0.766919
# 2    -0.766919
# 3    -0.766919
# 4     1.303918
# ...        ...
# 3994  1.303918
# 3995  1.303918
# 3996  1.303918
# 3997 -0.766919
# 3998 -0.766919
#
# [3999 rows x 11 columns]

# %%
#method=single
#dendograms
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10, 7))
plt.title("Customer Dendograms")
dend = shc.dendrogram(shc.linkage(X, method='single'))

# %%
#AgglomerativeClustering
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=4, metric='euclidean', linkage='single')
Y = cluster.fit_predict(X)
Y
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#creating Y dataframe
Y_new = pd.DataFrame(Y)
#Y value counts
Y_new.value_counts()
# Out:
# 0
# 0    3955
# 1      28
# 2      15
# 3       1
# Name: count, dtype: int64

# %%
#Method = complete
#Dendograms

plt.figure(figsize=(30,15))
plt.title("Customer Dendograms")
dend = shc.dendrogram(shc.linkage(X, method='complete'))

# %%
#AgglomerativeClustering
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=5, metric='euclidean', linkage='complete')
Y = cluster.fit_predict(X)
Y
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
#creating Y dataframe
Y_new = pd.DataFrame(Y)
#Y value counts
Y_new.value_counts()
# Out:
# 0
# 1    3782
# 0     170
# 4      28
# 2      15
# 3       4
# Name: count, dtype: int64

# %%
#Method = averagee
#Dendograms

plt.figure(figsize=(30,15))
plt.title("Customer Dendograms")
dend = shc.dendrogram(shc.linkage(X, method='average'))

# %%
#AgglomerativeClustering
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='average')
Y = cluster.fit_predict(X)
Y
#creating Y dataframe
Y_new = pd.DataFrame(Y)
#Y value counts
Y_new.value_counts()
# Out:
# 0
# 0    3994
# 1       4
# 2       1
# Name: count, dtype: int64

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, n_init=20)

# %%
kmeans = kmeans.fit(X) # Fitting with inputs
#Predicting the clusters
Y = kmeans.predict(X)
#creating Y dataframe
Y_new = pd.DataFrame(Y)
#Y value counts
Y_new.value_counts()
# Out:
# 0
# 1    2522
# 2    1254
# 0     147
# 4      61
# 3      15
# Name: count, dtype: int64

# %%
#Total with in centroid sum of squares
kmeans.inertia_

clust = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(X)
    clust.append(kmeans.inertia_)

# %%
#Elbow method
plt.scatter(x=range(1,11), y=clust,color='red')
plt.plot(range(1,11), clust,color='black')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('inertial values')
plt.show()

# %%
#DBSCAN
X = df.iloc[:,1:].values
X

from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=3, min_samples=5)
#fitting dbscan
dbscan.fit(X)
# Out:
# DBSCAN(eps=3)

# %%
Y = dbscan.labels_
pd.DataFrame(Y).value_counts()
# Out:
# 0
#  0    3894
# -1      67
#  2      25
#  1      13
# Name: count, dtype: int64

# %%
#creating cluster id with dataframe
df["Cluster id"] = pd.DataFrame(Y)
df.head()
# Out:
#         ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0 -1.735125 -0.451141   -0.186299  -0.769578  -0.098242  -0.062767
# 1 -1.734263 -0.539457   -0.186299  -0.769578  -0.098242  -0.062767
# 2 -1.733402 -0.320031   -0.186299  -0.769578  -0.098242  -0.062767
# 3 -1.732540 -0.583799   -0.186299  -0.769578  -0.098242  -0.062767
# 4 -1.731679  0.239678   -0.186299   1.409471  -0.098242  -0.062767
#
#    Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0    -0.702786    -1.104065          -0.328603        -0.362168
# 1    -0.701088    -0.999926          -0.328603        -0.362168
# 2    -0.539253    -0.791649          -0.328603        -0.362168
# 3    -0.689286    -1.104065          -0.328603        -0.362168
# 4     1.083121     1.499394           1.154932         0.692490
#
#    Days_since_enroll    Award?  Cluster id
# 0           1.395454 -0.766919           0
# 1           1.379957 -0.766919           0
# 2           1.411920 -0.766919           0
# 3           1.372208 -0.766919           0
# 4           1.363975  1.303918           0

# %%
#final data
Finaldata = df[(df["Cluster id"] == 0)| (df["Cluster id"] == 1)
               |(df["Cluster id"] == 2)].reset_index(drop=True)
Finaldata
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0    -1.735125 -0.451141   -0.186299  -0.769578  -0.098242  -0.062767
# 1    -1.734263 -0.539457   -0.186299  -0.769578  -0.098242  -0.062767
# 2    -1.733402 -0.320031   -0.186299  -0.769578  -0.098242  -0.062767
# 3    -1.732540 -0.583799   -0.186299  -0.769578  -0.098242  -0.062767
# 4    -1.731679  0.239678   -0.186299   1.409471  -0.098242  -0.062767
# ...        ...       ...         ...        ...        ...        ...
# 3927  1.725097 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767
# 3928  1.725958 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767
# 3929  1.726820 -0.000043   -0.186299   0.683121  -0.098242  -0.062767
# 3930  1.727682 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767
# 3931  1.728543 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0       -0.702786    -1.104065          -0.328603        -0.362168
# 1       -0.701088    -0.999926          -0.328603        -0.362168
# 2       -0.539253    -0.791649          -0.328603        -0.362168
# 3       -0.689286    -1.104065          -0.328603        -0.362168
# 4        1.083121     1.499394           1.154932         0.692490
# ...           ...          ...                ...              ...
# 3927    -0.356960    -0.791649          -0.185750        -0.098503
# 3928    -0.669367    -0.687511          -0.328603        -0.362168
# 3929     0.343804    -0.375096          -0.328603        -0.362168
# 3930    -0.689286    -1.104065           0.028531        -0.098503
# 3931    -0.709992    -1.208203          -0.328603        -0.362168
#
#       Days_since_enroll    Award?  Cluster id
# 0              1.395454 -0.766919           0
# 1              1.379957 -0.766919           0
# 2              1.411920 -0.766919           0
# 3              1.372208 -0.766919           0
# 4              1.363975  1.303918           0
# ...                 ...       ...         ...
# 3927          -1.315120  1.303918           0
# 3928          -1.318994  1.303918           0
# 3929          -1.315604  1.303918           0
# 3930          -1.316088 -0.766919           0
# 3931          -1.317541 -0.766919           0
#
# [3932 rows x 13 columns]
