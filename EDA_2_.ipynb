# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("https://raw.githubusercontent.com/ygtech27/Datasets/refs/heads/main/adult_with_headers.csv")
data
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
data.head(10)
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital_status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
data.tail(10)
# Out:
#        age      workclass  fnlwgt      education  education_num  \
# 32551   32        Private   34066           10th              6
# 32552   43        Private   84661      Assoc-voc             11
# 32553   32        Private  116138        Masters             14
# 32554   53        Private  321865        Masters             14
# 32555   22        Private  310152   Some-college             10
# 32556   27        Private  257302     Assoc-acdm             12
# 32557   40        Private  154374        HS-grad              9
# 32558   58        Private  151910        HS-grad              9
# 32559   22        Private  201490        HS-grad              9
# 32560   52   Self-emp-inc  287927        HS-grad              9
#
#             marital_status          occupation    relationship  \
# 32551   Married-civ-spouse   Handlers-cleaners         Husband
# 32552   Married-civ-spouse               Sales         Husband
# 32553        Never-married        Tech-support   Not-in-family
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
df = data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Check basic info and missing values
print(df.info())
print(df.describe())

# Handle missing values: Median for numerical, most frequent for categorical
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
cat_cols = df.select_dtypes(include=['object']).columns

df[num_cols] = SimpleImputer(strategy='median').fit_transform(df[num_cols])
df[cat_cols] = SimpleImputer(strategy='most_frequent').fit_transform(df[cat_cols])

# Apply scaling
standard_scaled = StandardScaler().fit_transform(df[num_cols])
minmax_scaled = MinMaxScaler().fit_transform(df[num_cols])

# Standard scaling is used when data follows a normal distribution. Min-Max scaling is preferred when data has a set range.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None
# ...

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# Reload the dataset to restore all columns
df = pd.read_csv("https://raw.githubusercontent.com/ygtech27/Datasets/refs/heads/main/adult_with_headers.csv")

# Check categorical columns again
cat_cols = df.select_dtypes(include=['object']).columns

# One-Hot Encoding for categorical variables with < 5 categories
small_cat_cols = [col for col in cat_cols if df[col].nunique() < 5]

# Label Encoding for categorical variables with >= 5 categories
large_cat_cols = [col for col in cat_cols if df[col].nunique() >= 5]

# Apply Label Encoding BEFORE applying One-Hot Encoding
le = LabelEncoder()
for col in large_cat_cols:
    df[col] = le.fit_transform(df[col])

# Now apply One-Hot Encoding
df = pd.get_dummies(df, columns=small_cat_cols, drop_first=True)

# Check if 'sex' was encoded and its new binary columns
print(df.columns)
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'capital_gain',
#        'capital_loss', 'hours_per_week', 'native_country', 'sex_ Male',
#        'income_ >50K'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Create new features (example)
df['age_hours_per_week'] = df['age'] * df['hours_per_week']

# Apply log transformation to skewed data (example on 'capital_gain')
df['capital_gain_log'] = df['capital_gain'].apply(lambda x: np.log1p(x))

# Apply scaling to numerical columns
num_cols = ['age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss', 'hours_per_week']

# Standard Scaling
scaler = StandardScaler()
df_standard_scaled = df.copy()
df_standard_scaled[num_cols] = scaler.fit_transform(df[num_cols])

# Min-Max Scaling
minmax_scaler = MinMaxScaler()
df_minmax_scaled = df.copy()
df_minmax_scaled[num_cols] = minmax_scaler.fit_transform(df[num_cols])

# Now you can proceed with model training or further preprocessing steps.

# %%
from sklearn.ensemble import IsolationForest

# Detect outliers using Isolation Forest
iso_forest = IsolationForest(contamination=0.01)
outliers = iso_forest.fit_predict(df[num_cols])

# Keep only non-outliers
df = df[outliers == 1]

# Outliers can skew model performance and reduce accuracy.

# %%
import ppscore as pps
import seaborn as sns
import matplotlib.pyplot as plt

# Compute PPS and plot
pps_matrix = pps.matrix(df)[['x', 'y', 'ppscore']].pivot(columns='x', index='y', values='ppscore')
sns.heatmap(pps_matrix, annot=True, cmap="coolwarm")
plt.show()

# Compare with correlation matrix
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.show()
